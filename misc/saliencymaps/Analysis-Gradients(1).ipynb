# %% [markdown]
# # Feature Analysis (Gradients - Saliency Maps)

# %%
from phply.phpparse import make_parser
from phply import phpast as ast
from phply import phplex
from data.preprocessing import sub_tokens
from data.wirecaml_utils.my_php_listener import MyPHPListener
from data.wirecaml_utils.phptraverser import php_traverser
import intervaltree
import os
import re
import pickle
import torch
from model import PhpNetGraphTokensCombine
from data.preprocessing import sub_tokens
from data.preprocessing import map_tokens
from torch_geometric.data import Data
import main
import numpy as np
from torch_geometric.data import DataLoader, DataListLoader, Batch
import random
import pandas as pd
import activations as act

seed = 1234
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# directory to search
dir = "data/SARD/SQLi/CWE_89/unsafe"

data_ls = []
no_flaws = 0
parser = make_parser()
lexer = phplex.lexer.clone()
ignore_tokens = ['LBRACE','RBRACE']

def process(line, allfuncs,allvars):
    lexer = phplex.lexer.clone()
    code_tokens = []
    lexer.input("<?php " + line)
    while True:
        tok = lexer.token()
        if not tok:
            break
        if tok in ignore:
            continue
        tok = sub_tokens.sub_token(tok,None,allvars)
        code_tokens.append(tok)
    return map_tokens.tokenise(code_tokens)

def getLines(filepath):
    lines = []
    with open(filepath) as f:
        s = f.read()
        inserts_deletes = s.split("@@")
        for phrase in inserts_deletes:
            if phrase is None or phrase == '' or phrase == ' ' or phrase == '\n':
                continue
            out = re.split(" |,|\-",phrase)
            out = list(filter(lambda i: i != '',out))
            if ('+' in out[len(out) - 1]) or ('+' not in out[len(out) - 1] and int(out[len(out) - 1]) > 0):
                lines.append(int(out[0]))
    return lines

def get_tokens(data):
    lexer2 = phplex.lexer.clone()
    lexer2.input(data)
    codetokens = []
    synerror = False
    while True:
        try:
            tok = lexer2.token()
        except IndexError:
            break
        except SyntaxError:
            print("syntax error :(")
            synerror = True
            break
        if not tok:
            break
        if tok in ignore:
            continue
        tok = sub_tokens.sub_token(tok)
        codetokens.append(tok)
    if synerror:
        return None
    return codetokens

def RepresentsInt(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

def _compute_interval(node):
    min_lineno = node.lineno
    max_lineno = node.lineno

    allsubnodes = []
    def visitor_subnodes(node):
        if isinstance(node, ast.Node):
            allsubnodes.append(node)
    node.accept(visitor_subnodes)
    for node in allsubnodes:
        if hasattr(node, "lineno") and node.lineno != None and node.lineno != 0:
            min_lineno = min(min_lineno, node.lineno)
            max_lineno = max(max_lineno, node.lineno)
    return (min_lineno, max_lineno + 1)

def file_to_tree(filename):
    parser = make_parser()
    lexer = phplex.lexer.clone()
    try:
        with open(filename,encoding='utf-8') as f:
            file_content = f.read()
            if len(file_content.split("<?php")) > 2:
                return None
            parsed = parser.parse(file_content, lexer=lexer)
    except UnicodeDecodeError:
        print("error decoding " + filename)
        return None
    except SyntaxError:
        print("error syntax " + filename)
        return None
    tree = intervaltree.IntervalTree()
    allnodes = []
    def visitor(node):
        if isinstance(node, ast.Function):
            allnodes.append(node)
        elif isinstance(node, ast.Method):
            allnodes.append(node)

    for node in parsed:
        node.accept(visitor)

    for node in allnodes:
        if isinstance(node, (ast.Function, ast.Class, ast.Method)):
            start, end = _compute_interval(node)
            tree[start:end] = node
    return tree



device=torch.device('cuda')

def get_all_funcs(nodes):
    allfuncs = []
    for node in nodes:
        allfuncs.extend(node.stmt_funcs)
    return allfuncs
vuln_dict = {1:"SQLi",2:"XSS",3:"CI"}
model = PhpNetGraphTokensCombine()
model.load_state_dict(torch.load("model_combine.pt"))
model.to("cuda")
model.eval()

model = act.set_eval_zerodrop(model)

ignore = {'WHITESPACE', 'OPEN_TAG', 'CLOSE_TAG'}
vulns = 0
funcs = 0
predicted = []

########## START  ADDED

all_pred=[]
all_lbl=[]
all_codes=[]
all_graphs=[]
all_graphs_len=[]
sensitivity_grad=[]
sensitivity_grad_graph=[]
all_filenames=[]

target_vuln = 1 # 9999 if UNKNOWN


all_grad=[]
all_grad_graph=[]
########END ADDED

for root, dirs, files in os.walk(dir):
    for filename in files:
        file = root + os.sep + filename
        if ".php" in file:
            matches = file_to_tree(file)
            # print(matches)
            if matches is None or len(matches) == 0:
                matches = [None]

            if matches:
                for match in matches:
                    funcs += 1
                    with open(file, "r") as myfile:
                        code_tokens = []
                        lexer = phplex.lexer.clone()
                        parser = make_parser()
                        if match is not None:
                            interval = min([match], key=lambda i: i[1] - i[0])

                            func_lines = ["<?php "]
                            startsopen = False
                            no_braces = 0
                            try:
                                for i, line in enumerate(myfile):
                                    if i >= interval[1]:
                                        break
                                    elif i >= interval[0]:
                                        if line.strip() == "{" and i == interval[0]:
                                            startsopen = True
                                            continue
                                        elif line.strip() == "}" and i == (interval[1] - 1) and no_braces == 0:
                                            continue

                                        if '{' in line:
                                            no_braces += line.count('{')
                                        if '}' in line:
                                            no_braces -= line.count('}')
                                        func_lines.append(line)
                            except UnicodeDecodeError:
                                print("unidecode error")
                                continue
                            data = ''.join(func_lines)
                        else:
                            try:
                                data = myfile.read()
                            except UnicodeDecodeError:
                                print("unidecode error")
                                continue
                        try:
                            nodes = parser.parse(data, lexer=lexer, tracking=True, debug=False)
                        except:
                            print("parsing error")
                            print("here " + file)
                            continue
                        listener = MyPHPListener(name=file)

                        php_traverser.traverse(nodes, listener)

                        cfg = listener.get_graph()
                        allvars = set()
                        for node in list(cfg.nodes):
                            for var in node.stmt_vars:
                                allvars.add(var)

                        allfuncs = get_all_funcs(cfg.nodes)
                        edges = [[list(cfg.nodes).index(i), list(cfg.nodes).index(j)] for (i, j) in cfg.edges]


                        if len(edges) == 0:
                            continue
                        edges = torch.tensor(edges, dtype=torch.long)
                        try:
                            graph_nodes = torch.tensor([process(node.text, allfuncs, list(allvars)) for node in list(cfg.nodes)])
                        except Exception as e:
                            print("Tokenising error " + file)
                            continue
                        data_graph = Data(x=graph_nodes, edge_index=edges.t().contiguous())
                        lexer = phplex.lexer.clone()
                        lexer.input(data)
                        synerror = False
                        while True:
                            try:
                                tok = lexer.token()
                            except IndexError:
                                break
                            except SyntaxError:
                                print("syntax error :(")
                                synerror = True
                                break
                            if not tok:
                                break
                            if tok in ignore:
                                continue
                            tok = sub_tokens.sub_token(tok,allfuncs,list(allvars))
                            code_tokens.append(tok)
                        
                        out1,out2 = act.get_graph_tokens(graph_nodes) ## added
                        all_graphs.append(out1) ## added
                        all_graphs_len.append(out2) ## added
                        all_filenames.append(file) ## added
                        data_tokens,encoder = main.get_data_custom([code_tokens]) ## edited, return encoder
                        all_codes.append(np.array(data_tokens[0].detach()).astype(int)) ## added
                        all_lbl.append(target_vuln) ## added
                        
                        data_token_in = data_tokens.to(device=device, dtype=torch.long)
                        data_graph_batch = Batch.from_data_list([data_graph]).to(device)
                        pred = model(data_graph_batch,data_token_in)
                        
                        sensitivity_weight,sensitivity_grad_batch,grad = act.get_weights_grads_from_model(model,pred,'embed') ## added
                        sensitivity_grad.append(sensitivity_grad_batch) ## added
                        all_grad.append(grad) ## added
                        
                        sensitivity_weight_graph,sensitivity_grad_graph_batch,grad_graph = act.get_weights_grads_from_model(model,pred,'embed1') ## added
                        sensitivity_grad_graph.append(sensitivity_grad_graph_batch) ## added
                        all_grad_graph.append(grad_graph) ## added
                        
                        vals = pred.cpu().detach().numpy()
                        preds = np.argmax(vals, axis=1)
                        if preds > 0:
                            all_pred.append(preds[0]) ## added
                            print("Found Vuln")
                            print(vuln_dict[preds[0]])
                            predicted.append(vuln_dict[preds[0]])
                            print("in")
                            print(file)
                            if match is not None:
                                print("function")
                                print(match[2])
                            #print("code body is")
                            #print(data)
                            print("NEXT")
                            vulns+=1
                        else:
                            all_pred.append(0) ## added
                            predicted.append('Safe')


print('\nTotal predicted as vulnerable: ',vulns)
print('Total functions: ',funcs)
print('\nPredicted distribution:')
print(pd.value_counts(predicted))
# Out:
# 4416
# (9878, 2)
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__array-GET__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__backticks__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__exec__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_mysql_real_escape_string__multiple_AS-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_mysql_real_escape_string__multiple_AS-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__fopen__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__GET__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__popen__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__POST__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__proc_open__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# ...
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__shell_exec__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# CI
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__system__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-full_special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-full_special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-full_special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-full_special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-full_special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-full_special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-special_chars_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-special_chars_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-special_chars_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-special_chars_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-special_chars_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-CLEANING-special_chars_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-VALIDATION-email_filter__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-VALIDATION-email_filter__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-VALIDATION-email_filter__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-VALIDATION-email_filter__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-VALIDATION-email_filter__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_FILTER-VALIDATION-email_filter__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_mysql_real_escape_string__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_mysql_real_escape_string__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_mysql_real_escape_string__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_mysql_real_escape_string__select_from_where-interpretation.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_preg_match-no_filtering__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_preg_match-no_filtering__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_preg_match-no_filtering__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_preg_match-no_filtering__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_preg_match-no_filtering__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# XSS
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__func_preg_match-no_filtering__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__join-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__join-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__join-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_AS-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_AS-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_AS-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_AS-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_AS-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_select-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_select-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_select-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_select-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__multiple_select-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from-sprintf_%s_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from_where-concatenation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from_where-concatenation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from_where-interpretation.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from_where-interpretation_simple_quote.php
# NEXT
# Found Vuln
# SQLi
# in
# data/SARD/SQLi/CWE_89/unsafe\CWE_89__unserialize__no_sanitizing__select_from_where-sprintf_%s_simple_quote.php
# NEXT
#
# Total predicted as vulnerable:  555
# Total functions:  1083
#
# Predicted distribution:
# SQLi    410
# Safe    243
# CI       87
# XSS      58
# dtype: int64

# %%
mydf = act.process_activation(sensitivity_weight, 
                              sensitivity_grad,
                              all_codes,
                              encoder,
                              all_pred,
                              all_lbl,
                              all_filenames)

# %%
mydf_graph = act.process_activation(sensitivity_weight_graph, 
                              sensitivity_grad_graph,
                              all_graphs,
                              map_tokens.encoder,
                              all_pred,
                              all_lbl,
                              all_filenames,
                              all_graphs_len)

# %%
mydf[mydf.label==mydf.predicted].index[50:70]
# Out:
# Int64Index([ 73,  75,  76,  77,  78,  79,  80,  83,  84,  85,  86, 101, 103,
#             109, 111, 114, 115, 116, 117, 118],
#            dtype='int64')

# %%
idx = 0

# %%
#act.display_weights(mydf,idx)

# %%
#act.display_weights(mydf_graph,idx)

# %%
act.display_activations(mydf,idx)
# Out:
# Label: 1 <br /> Predicted: 1 <br /> Number of UNKNOWN tokens: 0 <br />Distribution of activations: <font style="background: rgba(255,255,255, 0.5)">0.0</font> <font style="background: rgba(0,0,255, 0.5)">0.1</font> <font style="background: rgba(0,206,209, 0.5)">0.2</font> <font style="background: rgba(0,128,0, 0.5)">0.3</font> <font style="background: rgba(153,255,204, 0.5)">0.4</font> <font style="background: rgba(95,158,160, 0.5)">0.5</font> <font style="background: rgba(255,128,0, 0.5)">0.6</font> <font style="background: rgba(255,0,255, 0.5)">0.7</font> <font style="background: rgba(255,0,0, 0.5)">0.8</font> <font style="background: rgba(128,0,0, 0.5)">0.9</font> <br /> <br /><font style="background: rgba(153,255,204, 0.500)">VAR3</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(0,206,209, 0.500)">ARRAY</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(153,255,204, 0.500)">VAR3</font>
# <font style="background: rgba(0,0,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(0,206,209, 0.500)">RBRACKET</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(153,255,204, 0.500)">VAR3</font>
# <font style="background: rgba(0,0,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(0,206,209, 0.500)">RBRACKET</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">$_GET</font>
# <font style="background: rgba(0,0,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(0,206,209, 0.500)">RBRACKET</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(153,255,204, 0.500)">VAR3</font>
# <font style="background: rgba(0,0,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(0,206,209, 0.500)">RBRACKET</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR1</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(153,255,204, 0.500)">VAR3</font>
# <font style="background: rgba(0,0,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(255,255,255, 0.500)">LNUMBER</font>
# <font style="background: rgba(0,206,209, 0.500)">RBRACKET</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR2</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">FILTER_VAR</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR1</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(255,255,255, 0.500)">FILTER_SANITIZE_EMAIL</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">IF</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">FILTER_VAR</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR2</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(255,255,255, 0.500)">FILTER_VALIDATE_EMAIL</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR1</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR2</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">ELSE</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR1</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR0</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(0,0,255, 0.500)">ENCAPSED_AND_WHITESPACE</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR1</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(0,0,255, 0.500)">ENCAPSED_AND_WHITESPACE</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(0,128,0, 0.500)">VAR7</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">MYSQL_CONNECT</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">MYSQL_SELECT_DB</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">ECHO</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(0,0,255, 0.500)">ENCAPSED_AND_WHITESPACE</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR0</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(0,0,255, 0.500)">ENCAPSED_AND_WHITESPACE</font>
# <font style="background: rgba(0,206,209, 0.500)">QUOTE</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR5</font>
# <font style="background: rgba(153,255,204, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">MYSQL_QUERY</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR0</font>
# <font style="background: rgba(0,128,0, 0.500)">RPAREN</font>
# <font style="background: rgba(128,0,0, 0.500)">SEMI</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">WHILE</font>
# <font style="background: rgba(255,128,0, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">

# %%
act.display_activations(mydf_graph,idx)
# Out:
# Label: 1 <br /> Predicted: 1 <br /> Number of UNKNOWN tokens: 0 <br />Distribution of activations: <font style="background: rgba(255,255,255, 0.5)">0.0</font> <font style="background: rgba(0,0,255, 0.5)">0.1</font> <font style="background: rgba(0,206,209, 0.5)">0.2</font> <font style="background: rgba(0,128,0, 0.5)">0.3</font> <font style="background: rgba(153,255,204, 0.5)">0.4</font> <font style="background: rgba(95,158,160, 0.5)">0.5</font> <font style="background: rgba(255,128,0, 0.5)">0.6</font> <font style="background: rgba(255,0,255, 0.5)">0.7</font> <font style="background: rgba(255,0,0, 0.5)">0.8</font> <font style="background: rgba(128,0,0, 0.5)">0.9</font> <br /> <br /><font style="background: rgba(255,255,255, 0.500)">VAR3</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(255,255,255, 0.500)">RBRACKET</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">LBRACE</font>
# <font style="background: rgba(255,255,255, 0.500)">MOD</font>
# <font style="background: rgba(255,255,255, 0.500)">DO</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR3</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">MINUS</font>
# <font style="background: rgba(255,255,255, 0.500)">MOD</font>
# <font style="background: rgba(255,255,255, 0.500)">RBRACE</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">LBRACE</font>
# <font style="background: rgba(255,255,255, 0.500)">MOD</font>
# <font style="background: rgba(255,255,255, 0.500)">DO</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR3</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">$_GET</font>
# <font style="background: rgba(255,255,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">RBRACKET</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">MINUS</font>
# <font style="background: rgba(255,255,255, 0.500)">MOD</font>
# <font style="background: rgba(255,255,255, 0.500)">RBRACE</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">LBRACE</font>
# <font style="background: rgba(255,255,255, 0.500)">MOD</font>
# <font style="background: rgba(255,255,255, 0.500)">DO</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR3</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">MINUS</font>
# <font style="background: rgba(255,255,255, 0.500)">MOD</font>
# <font style="background: rgba(255,255,255, 0.500)">RBRACE</font>
# <br />
# <font style="background: rgba(0,0,255, 0.500)">VAR1</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR3</font>
# <font style="background: rgba(255,255,255, 0.500)">LBRACKET</font>
# <font style="background: rgba(255,255,255, 0.500)">LNUMBER</font>
# <font style="background: rgba(255,255,255, 0.500)">RBRACKET</font>
# <br />
# <font style="background: rgba(0,206,209, 0.500)">VAR2</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(0,206,209, 0.500)">FILTER_VAR</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,0,255, 0.500)">VAR1</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(255,255,255, 0.500)">FILTER_SANITIZE_EMAIL</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">IF</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,206,209, 0.500)">FILTER_VAR</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,206,209, 0.500)">VAR2</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(255,255,255, 0.500)">FILTER_VALIDATE_EMAIL</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <br />
# <font style="background: rgba(0,0,255, 0.500)">VAR1</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(0,206,209, 0.500)">VAR2</font>
# <br />
# <font style="background: rgba(0,0,255, 0.500)">VAR1</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR0</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">QUOTE</font>
# <font style="background: rgba(255,255,255, 0.500)">ENCAPSED_AND_WHITESPACE</font>
# <font style="background: rgba(255,255,255, 0.500)">QUOTE</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(0,0,255, 0.500)">VAR1</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">QUOTE</font>
# <font style="background: rgba(255,255,255, 0.500)">ENCAPSED_AND_WHITESPACE</font>
# <font style="background: rgba(255,255,255, 0.500)">QUOTE</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR7</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">MYSQL_CONNECT</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">COMMA</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">MYSQL_SELECT_DB</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">ECHO</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR0</font>
# <font style="background: rgba(255,255,255, 0.500)">CONCAT</font>
# <font style="background: rgba(0,206,209, 0.500)">CONSTANT_ENCAPSED_STRING</font>
# <br />
# <font style="background: rgba(255,255,255, 0.500)">VAR5</font>
# <font style="background: rgba(0,0,255, 0.500)">EQUALS</font>
# <font style="background: rgba(255,255,255, 0.500)">MYSQL_QUERY</font>
# <font style="background: rgba(255,255,255, 0.500)">LPAREN</font>
# <font style="background: rgba(255,255,255, 0.500)">VAR0</font>
# <font style="background: rgba(255,255,255, 0.500)">RPAREN</font>
# <br />
# <font st

# %%
act.display_func(mydf,idx)
# Out:
# <?php
# /*
# Unsafe sample
# input : get the $_GET['userData'] in an array
# Uses an email_filter via filter_var function
# construction : concatenation with simple quote
# */
#
#
#
# /*Copyright 2015 Bertrand STIVALET
#
# Permission is hereby granted, without written agreement or royalty fee, to
#
# use, copy, modify, and distribute this software and its documentation for
#
# any purpose, provided that the above copyright notice and the following
#
# three paragraphs appear in all copies of this software.
#
#
# IN NO EVENT SHALL AUTHORS BE LIABLE TO ANY PARTY FOR DIRECT,
#
# INDIRECT, SPECIAL, INCIDENTAL, OR CONSEQUENTIAL DAMAGES ARISING OUT OF THE
#
# USE OF THIS SOFTWARE AND ITS DOCUMENTATION, EVEN IF AUTHORS HAVE
#
# BEEN ADVISED OF THE POSSIBILITY OF SUCH DAMAGE.
#
#
# AUTHORS SPECIFICALLY DISCLAIM ANY WARRANTIES INCLUDING, BUT NOT
#
# LIMITED TO THE IMPLIED WARRANTIES OF MERCHANTABILITY, FITNESS FOR A
#
# PARTICULAR PURPOSE, AND NON-INFRINGEMENT.
#
#
# THE SOFTWARE IS PROVIDED ON AN "AS-IS" BASIS AND AUTHORS HAVE NO
#
# OBLIGATION TO PROVIDE MAINTENANCE, SUPPORT, UPDATES, ENHANCEMENTS, OR
#
# MODIFICATIONS.*/
#
#
# $array = array();
# $array[] = 'safe' ;
# $array[] = $_GET['userData'] ;
# $array[] = 'safe' ;
# $tainted = $array[1] ;
#
# $sanitized = filter_var($tainted, FILTER_SANITIZE_EMAIL);
# if (filter_var($sanitized, FILTER_VALIDATE_EMAIL))
#   $tainted = $sanitized ;
# else
#   $tainted = "" ;
#
# $query = "SELECT lastname, firstname FROM drivers, vehicles WHERE drivers.id = vehicles.ownerid AND vehicles.tag='". $tainted . "'";
#
# //flaw
# $conn = mysql_connect('localhost', 'mysql_user', 'mysql_password'); // Connection to the database (address, user, password)
# mysql_select_db('dbname') ;
# echo "query : ". $query ."<br /><br />" ;
#
# $res = mysql_query($query); //execution
#
# while($data =mysql_fetch_array($res)){
# print_r($data) ;
# echo "<br />" ;
# }
# mysql_close($conn);
#
# ?>
